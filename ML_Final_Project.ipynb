# %% [markdown]
# <a href="https://colab.research.google.com/github/Mazen-Morsy/ML-Final/blob/main/ML_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# test
